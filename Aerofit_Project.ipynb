# %% [markdown]
# <a href="https://colab.research.google.com/github/adityasingh-ops/Maths-assignment/blob/main/Aerofit_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Aerofit Project

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Aerofit, a leading fitness equipment brand, aims to enhance its marketing strategy by understanding the characteristics of its customer base in relation to the various treadmill products they offer. Specifically, the company seeks to identify the distinguishing features of customers who purchase each type of treadmill (KP281, KP481, and KP781). By doing so, Aerofit aims to tailor its marketing efforts more effectively to different customer segments, thereby increasing sales and customer satisfaction.

# %% [markdown]
# # **Sollution**

# %% [markdown]
# Here, we are trying to analyse the given data. we can provide company our further analysis. By this Aerofiit can gain valuable insights into its customer base and optimize its matketing strategy to drive business growth and enhance customer relationships.Aerofit can see our whole analysis like gender distribution in products. which machine is value for money to the customer etc.

# %% [markdown]
# # Basic

# %%
#Importing all the pacakages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#taking data given in the project

# %%
data = pd.read_csv("https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/001/125/original/aerofit_treadmill.csv?1639992749")

# %%
# Showing top 5 data

# %%
data.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   KP281   18    Male         14        Single      3        4   29562    112
# 1   KP281   19    Male         15        Single      2        3   31836     75
# 2   KP281   19  Female         14     Partnered      4        3   30699     66
# 3   KP281   19    Male         12        Single      3        3   32973     85
# 4   KP281   20    Male         13     Partnered      4        2   35247     47

# %%
# checking the shape of the data

# %%
data.shape
# Out:
# (180, 9)

# %%
# this mean we have 180 different data to analyse

# %%
#

# %%
#Now checking for the unique value

# %%
data.nunique()
# Out:
# Product           3
# Age              32
# Gender            2
# Education         8
# MaritalStatus     2
# Usage             6
# Fitness           5
# Income           62
# Miles            37
# dtype: int64

# %%
# checking the null value

# %%
data.isnull().sum().sum()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
#counting the no of null values

# %%
data.isna().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %%
#lets change the datatype of obect to category

# %%
data = data.astype({"Product":"category","Gender":"category", "MaritalStatus":"category"})
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    category
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    category
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    category
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: category(3), int64(6)
# memory usage: 9.5 KB

# %% [markdown]
# # statistical summary

# %%
# stats of all the integer data

# %%
data.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %% [markdown]
# here we have the all the statistical data of all integer row

# %% [markdown]
# **Observation**

# %% [markdown]
# *   there is no missing value in data
# *   there are three unique product
# *   Max and min age = 50 and 18
# *   most of the people have 16 year of education
# *   Standard deviation of incomes and miles are very high

# %% [markdown]
# # Gender

# %%
#analysing the gender in the given data

# %%
Gender_count = data['Gender'].value_counts()
print(Gender_count)
# Out:
# Male      104
# Female     76
# Name: Gender, dtype: int64

# %% [markdown]
# *  this mean mens buy more trademill
# *  and the value of men buying is 104 ans for female is 76 out of 180

# %% [markdown]
# # Product

# %%
#analysing the product data

# %%
Product_count = data['Product'].value_counts()
print(Product_count )
# Out:
# KP281    80
# KP481    60
# KP781    40
# Name: Product, dtype: int64

# %% [markdown]
# *  KP281 has highest sale as its price is low and also its for begibner
# *  KP781 has lowest sale

# %% [markdown]
# # Marital status

# %%
MaritalStatus = data['MaritalStatus'].value_counts()
print(MaritalStatus)
# Out:
# Partnered    107
# Single        73
# Name: MaritalStatus, dtype: int64

# %% [markdown]
# value show that the married couple buy more trademill than single

# %% [markdown]
# # Income

# %%
Income = data['Income'].value_counts()
print(Income)
# Out:
# 45480    14
# 52302     9
# 46617     8
# 54576     8
# 53439     8
#          ..
# 65220     1
# 55713     1
# 68220     1
# 30699     1
# 95508     1
# Name: Income, Length: 62, dtype: int64

# %% [markdown]
# *   data show that people have income around 50k buy more trademill
# *   people with low income and high income showing low interest

# %% [markdown]
# # Education

# %%
education = data['Education'].value_counts()
print(education)
# Out:
# 16    85
# 14    55
# 18    23
# 15     5
# 13     5
# 12     3
# 21     3
# 20     1
# Name: Education, dtype: int64

# %% [markdown]
# lot of buyer are have 14 to 16 year of education

# %% [markdown]
# # Usage

# %%
Usage = data['Usage'].value_counts()
print(Usage)
# Out:
# 3    69
# 4    52
# 2    33
# 5    17
# 6     7
# 7     2
# Name: Usage, dtype: int64

# %% [markdown]
# *   this show 69 user uses the mill trice a week (most of the user)
# *   only two user using it full week

# %% [markdown]
# # Miles

# %%
Miles = data['Miles'].value_counts()
print(Miles)
# Out:
# 85     27
# 95     12
# 66     10
# 75     10
# 47      9
# 106     9
# 94      8
# 113     8
# 53      7
# 100     7
# 180     6
# 200     6
# 56      6
# 64      6
# 127     5
# 160     5
# 42      4
# 150     4
# 38      3
# 74      3
# 170     3
# 120     3
# 103     3
# 132     2
# 141     2
# 280     1
# 260     1
# 300     1
# 240     1
# 112     1
# 212     1
# 80      1
# 140     1
# 21      1
# 169     1
# 188     1
# 360     1
# Name: Miles, dtype: int64

# %% [markdown]
# *   27 people cover 85 miles
# *   highest is 360 cover only by one of the people.

# %% [markdown]
# # **univariate** analysis

# %% [markdown]
# # Product

# %%
# Product
sns.countplot(data=data, y='Product', palette='YlGnBu')
plt.show()
# Out:
# <ipython-input-103-60a1efa6acd5>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=data, y='Product', palette='YlGnBu')

# %% [markdown]
# * KP281 is the most purchased product
# * KP481 is the second most purchased product
# * :Lastly KP781 is the purchased product

# %%
#box plot difference of 75th percentile and 25 percentile

# %%
sns.boxplot(data = data, x = 'Age', palette =  'YlGnBu')
plt.show()
# Out:
# <ipython-input-104-d4681f8f42e7>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data = data, x = 'Age', palette =  'YlGnBu')

# %%
q25, q75 = np.percentile(data['Age'],[25,75])
IQR = q75-q25
print(IQR)
# Out:
# 9.0

# %% [markdown]
# * Most common age range is roughly between 22 - 32.
# * There are few data points whose age is more than 46 years (Outlier).
# * Difference between 25th and 75th percentile is 9 years.

# %% [markdown]
# # Gender

# %%
sns.countplot(data = data, x = 'Gender', palette='YlGnBu')
plt.show()
# Out:
# <ipython-input-59-3ab3c88a716f>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data = data, x = 'Gender', palette='YlGnBu')

# %% [markdown]
# * Male is the most frequent buyer of the treadmills == 100.
# * Female is the second most frequent buyer with count of roughly around 75.

# %% [markdown]
# # Education

# %%
sns.countplot(data = data, x = 'Education', palette='YlGnBu')
plt.show()
# Out:
# <ipython-input-60-278db38a25fc>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data = data, x = 'Education', palette='YlGnBu')

# %%
sns.histplot(data=data, x='Education', color='purple', bins=10)
plt.show()

# %%
sns.distplot(data['Education'], kde=True, color='red')
plt.show()
# Out:
# <ipython-input-141-b930e72f7165>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Education'], kde=True, color='red')

# %% [markdown]
# * Most of the buyer have education is 16

# %% [markdown]
# # Marital Status

# %%
sns.countplot(data = data, x = 'MaritalStatus', palette='YlGnBu')
plt.show()
# Out:
# <ipython-input-62-c7a35fe986c9>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data = data, x = 'MaritalStatus', palette='YlGnBu')

# %% [markdown]
# * this plot show that most of them are couples who buy the trademill

# %% [markdown]
# # Usage

# %%
sns.boxplot(data = data, x= 'Usage')
plt.show()

# %%
sns.countplot(data = data, x = 'Usage', palette='YlGnBu')
plt.show()
# Out:
# <ipython-input-116-2d55677d9ac2>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data = data, x = 'Usage', palette='YlGnBu')

# %%
sns.histplot(data=data, x='Usage', color='purple', bins=10)
plt.show()

# %%
sns.distplot(data['Usage'], kde=True, color='red')
plt.show()
# Out:
# <ipython-input-119-7fe51112a5d3>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Usage'], kde=True, color='red')

# %%
q25 , q75 = np.percentile(data['Usage'],[25,75])
IQR = q75-q25
print(IQR)
# Out:
# 1.0

# %% [markdown]
# * Most of the customers use treadmill 3 - 4 times per week.
# * Very few people run on treadmill 6 - 7 times per week.
# * Difference between 25th and 75th percentile is 1.0.

# %% [markdown]
# # Miles

# %%
sns.boxplot(data = data, x = 'Miles')
plt.show()

# %%
sns.countplot(data = data, x = 'Miles', palette='YlGnBu')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-127-5b2e1c70e323>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data = data, x = 'Miles', palette='YlGnBu')

# %%
sns.distplot(data['Miles'], kde=True, color='red')
plt.show()
# Out:
# <ipython-input-128-e3c6e64ad2ea>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Miles'], kde=True, color='red')

# %%
sns.histplot(data=data, x='Miles', color='purple', bins=10)
plt.show()

# %%
q25 , q75 = np.percentile(data['Miles'],[25,75])
IQR = q75-q25
print(IQR)
# Out:
# 48.75

# %% [markdown]
# most of the distance travelled by the buyers is 75-120 miles.

# %% [markdown]
# # Income

# %%
sns.boxplot(data = data, x = 'Income')
plt.show()

# %%
sns.histplot(data=data, x='Income', color='purple', bins=10)
plt.show()

# %%
sns.distplot(data['Income'], kde=True, color='red')
plt.show()
# Out:
# <ipython-input-133-47de5b98024a>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Income'], kde=True, color='red')

# %%
sns.countplot(data = data, x = 'Income', palette='YlGnBu',)
plt.xticks(rotation=90)
plt.show()
# Out:
# <ipython-input-139-f00ceeebb6e8>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data = data, x = 'Income', palette='YlGnBu',linewidth=5, width=0.8)

# %%
q25 , q75 = np.percentile(data['Income'],[25,75])
IQR = q75-q25
print(IQR)
# Out:
# 14609.25

# %% [markdown]
# most of the buyers have income between 45k to 60k

# %% [markdown]
# # Fitness

# %%
sns.countplot(data = data, x = 'Fitness', palette='YlGnBu')
plt.show()
# Out:
# <ipython-input-69-8b4581f824d7>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data = data, x = 'Fitness', palette='YlGnBu')

# %%
sns.histplot(data=data, x='Fitness', color='purple', bins=10)
plt.show()

# %%
sns.distplot(data['Fitness'], kde=True, color='red')
plt.show()
# Out:
# <ipython-input-130-9846713469eb>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Fitness'], kde=True, color='red')

# %% [markdown]
# Distribution of customers rating of 2 & 4 are roughly same.

# %% [markdown]
# # Correlational Graph

# %%
# heatmap
sns.heatmap(data.corr(), annot=True, cmap='YlGnBu')
plt.show()
# Out:
# <ipython-input-70-0b8417f2c067>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(), annot=True, cmap='YlGnBu')

# %% [markdown]
# here we can see the correlation between all like correlation between age and  Income is 0.51 and similarly we can see all the correlation

# %%
#pairplot
sns.pairplot(data, palette='winter', hue='Gender', kind='reg')
plt.show()

# %% [markdown]
# same as heatplot

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# # **Statistical**

# %%
data.groupby('Product')['Income'].mean()
# Out:
# Product
# KP281    46418.025
# KP481    48973.650
# KP781    75441.575
# Name: Income, dtype: float64

# %%
data.groupby('Product')['Usage'].mean()
# Out:
# Product
# KP281    3.087500
# KP481    3.066667
# KP781    4.775000
# Name: Usage, dtype: float64

# %%
data.groupby('Product')['Fitness'].mean()
# Out:
# Product
# KP281    2.9625
# KP481    2.9000
# KP781    4.6250
# Name: Fitness, dtype: float64

# %% [markdown]
# # **Graphical**

# %%
sns.countplot(data=data, x='Product', hue='Gender')
plt.show()

# %% [markdown]
# KP281 has equal distribution in both gender while KP781 have great difference

# %%
sns.kdeplot(data=data, x='Age', hue='Gender')
plt.show()

# %% [markdown]
# here we can see the density of the male with greater age relative then the female is higher.

# %%
sns.kdeplot(data=data, x='Education', hue='Gender')
plt.show()

# %% [markdown]
# education of women  is lower then men but at specific age it is greater

# %%
sns.kdeplot(data=data, x='Income', hue='Gender')
plt.show()

# %% [markdown]
#  income of male and female is same but at some higher salary men density is more

# %%
sns.kdeplot(data=data, x='Miles', hue='Gender')
plt.show()

# %% [markdown]
# density of women and men at 0- 130 is almost same but after men density is higher

# %%
sns.kdeplot(data=data, x='Fitness', hue='Gender')
plt.show()

# %% [markdown]
# same in fitness range 0-4 but then after men have higher.

# %%
sns.countplot(data=data, x='MaritalStatus', hue='Gender')
plt.show()

# %% [markdown]
# female are lower in both the cases

# %%
sns.countplot(data=data, x='Usage', hue='Gender')
plt.show()

# %% [markdown]
# higher usage of male at most days of the week

# %%
sns.catplot(x='Gender',y='Income', hue='Product', col='MaritalStatus', data=data, kind='bar', palette='winter')
plt.show()

# %% [markdown]
# **Conclusion**
#
#
# 1.

# %% [markdown]
# this show  differently how the single, partnered, income and gender wise for product
# * most expensive trademill buyed by the single female have income 80k

# %% [markdown]
# # **Probability Analysis**

# %% [markdown]
# # Marginal Probability

# %%
sns.countplot(x = "Product", data= data, hue = "Gender")
plt.xlabel("Products")
plt.title("Count of Male and Female uses Particular Products")
plt.show()

# %%
sns.heatmap(pd.crosstab([data.Product],data.Gender,margins=True),annot=True, cmap='Spectral_r')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.heatmap(np.round(((pd.crosstab(data.Product,data.Gender,margins=True))/180)*100,2),annot=True, cmap='Spectral_r')
# Out:
# <Axes: xlabel='Gender', ylabel='Product'>

# %%
pd.crosstab([data.Product],data.Gender,margins=True)
# Out:
# Gender   Female  Male  All
# Product
# KP281        40    40   80
# KP481        29    31   60
# KP781         7    33   40
# All          76   104  180

# %%
np.round(((pd.crosstab(data.Product,data.Gender,margins=True))/180)*100,2)
# Out:
# Gender   Female   Male     All
# Product
# KP281     22.22  22.22   44.44
# KP481     16.11  17.22   33.33
# KP781      3.89  18.33   22.22
# All       42.22  57.78  100.00

# %% [markdown]
# **Marginal Probability**
#
# * Probability of Male Customer Purchasing any product is : 57.77 %
#
# * Probability of Female Customer Purchasing any product is : 42.22 %
#
# * Marginal Probability of any customer buying
#
# * product KP281 is : 44.44 % (cheapest / entry level product)
#
# * product KP481 is : 33.33 % (intermediate user level product)
#
# * product KP781 is : 22.22 % (Advanced product with ease of use that help incovering longer distance)

# %% [markdown]
# # Condtional Probability

# %%
sns.heatmap(pd.crosstab(data['Gender'], data['Product'], normalize='index'), annot=True, cmap='Spectral_r')
plt.show()

# %% [markdown]
# **Conditional Probability, P(Product | Gender)**
# * Probability of buying KP281 given that the customer is male, P(Product=KP281 | Customer=Male) = 0.38.
#
# * Probability of buying KP481 given that the customer is male, P(Product=KP481 | Customer=Male) = 0.3.
#
# * Probability of buying KP781 given that the customer is male, P(Product=KP781 | Customer=Male) = 0.32.
#
# * Probability of buying KP281 given that the customer is female, P(Product=KP281 | Customer=Female) = 0.53.
#
# * Probability of buying KP481 given that the customer is female, P(Product=KP481 | Customer=Female) = 0.38.
#
# * Probability of buying KP781 given that the customer is female, P(Product=KP781 | Customer=Female) = 0.092.

# %%
sns.heatmap(pd.crosstab(data['Gender'], data['Product'], normalize='columns'), annot=True, cmap='Spectral_r')
plt.show()

# %% [markdown]
# **Conditional Probability, P(Gender | Product)**
# * Probability that customer is Male given that he bought KP281, P(Customer=Male | Producty=KP281) = 0.50.
#
# * Probability that customer is Female given that she bought KP281, P(Customer=Female | Product=KP281) = 0.50.
#
# * Probability that customer is Male given that he bought KP481, P(Customer=Male | Product=KP481) = 0.52.
#
# * Probability that customer is Female given that she bought KP481, P(Customer=Female | Product=KP481) = 0.48.
#
# * Probability that customer is Male given that he bought KP781, P(Customer=Male | Product=781) = 0.82.
#
# * Probability that customer is Female given that he bought KP781, P(Customer=Female | Product=KP781) = 0.17.

# %%
sns.heatmap(pd.crosstab(data['Gender'], data['Product'], normalize=True), annot=True, cmap='Spectral_r')
plt.show()

# %% [markdown]
# **Joint Probability, P(Product Intersection Gender)**
# * Probability that customer buys KP281 and gender is Male, P(KP281 Intersection Male) = 0.22.
# * Probability that customer buys KP481 and gender is Male, P(KP481 Intersection Male) = 0.17.
# * Probability that customer buys KP781 and gender is Male, P(KP781 Intersection Male) = 0.18.
# * Probability that customer buys KP281 and gender is Female, P(KP281 Intersection Female) = 0.22.
# * Probability that customer buys KP481 and gender is Female, P(KP481 Intersection Female) = 0.16.
# * Probability that customer buys KP781 and gender is Female, P(KP781 Intersection Female) = 0.039.

# %% [markdown]
# # Conclusion
#
# * KP281 is the most popular treadmill, followed by KP481 and then KP781.
# * There are more male buyers than female overall.
# * Partnered buyers outnumber singles in treadmill purchases.
# * The average age of customers is 28, with a range from 18 to 50 years old.
# * Customers have an average education of 15.5 years, ranging from 2 to 21 years.
# * On average, customers plan to use the treadmill three times per week, with a maximum usage of seven times per week.
# * Customers rate their fitness at an average of 3 out of 5, with a range from 1 to 5.
# * The average annual income of customers is $53.7K, ranging from $29.5K to $104K.
# * Customers travel an average of 103 miles on the treadmill, with a range from 21 to 360 miles.
# * There is a moderately strong relationship between education and income.
# * Strong relationships exist between fitness and distance travelled, as well as between usage and distance travelled.
# * The age difference between the 25th and 75th percentiles is nine years, and the education difference is two years.
# * Most customers use the treadmill 3-4 times per week, with fewer using it 6-7 times per week.
# * The majority of customers rate themselves as moderately fit.
# * Income varies across treadmill types, with KP781 buyers having the highest income.
# * Usage and fitness levels differ among treadmill types, with KP781 users having higher levels.
# * Males prefer KP781 treadmills more than females, and overall, males tend to use treadmills more frequently.
# * Income distribution is similar between genders, but males tend to rate themselves as fitter.
# * Both genders travel similar distances on the treadmill, but men tend to exceed 320 miles.
# * Partnered individuals tend to be fitter than singles.

# %% [markdown]
# # Recomandation
#
# * Position KP281 and KP481 as budget-friendly options: Since customers with incomes ranging from 39K to 53K prefer these models, they should be marketed as affordable choices suitable for general fitness enthusiasts.
#
# * Promote KP781 for professionals and athletes: Given its advanced features, KP781 should be targeted towards serious fitness enthusiasts, athletes, and professionals. Using endorsements from sports figures like Neeraj Chopra can enhance its appeal.
#
# * Leverage special occasions for marketing: Capitalize on events like Women's Day and Mother's Day to encourage more female customers to engage in fitness activities. This can involve special promotions or campaigns targeting women.
#
# * Explore the market for customers above 50 years: Research and develop strategies to attract customers above 50 years of age by highlighting the benefits of starting with basic treadmill models like KP281 and KP481 for beginners.
#
# * Encourage upgrades for increased usage: As customers' usage of treadmills increases over time, recommend upgrading to higher-end models to cater to their evolving needs. This approach can lead to increased revenue through repeat purchases and upgrades.
